# %% [markdown]
# # Gini and Mobility prediction

# %%
library(haven)
library(sdazar)
library(ggplot2)

# %%
dat = data.table(read_dta('../../health_inequality_project/data/cty_full_covariates.dta'))

# %%
dim(dat)
# Out:
# [1] 3138   83

# %%
lookvar(dat, 'rank')

# %%
dat = dat[complete.cases(dat[, .(gini99,s_rank)])]

# %%
m = lm(s_rank ~ gini99 + I(gini99^2) + I(gini99^3), data=dat)

# %%
ggplot(data=dat, aes(x=gini99, y=s_rank)) +
    geom_point()
# Out:
# plot without title

# %%
preds = predict(m)

# %%
summary(m)
# Out:
# Call:
# lm(formula = s_rank ~ gini99 + I(gini99^2) + I(gini99^3), data = dat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -32.637  -5.104   0.110   5.181  32.449
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -14.510      4.138  -3.507 0.000461 ***
# gini99       191.270     26.610   7.188 8.35e-13 ***
# I(gini99^2) -247.748     53.650  -4.618 4.05e-06 ***
# I(gini99^3)   90.908     33.587   2.707 0.006837 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.923 on 2869 degrees of freedom
# Multiple R-squared:  0.1521,	Adjusted R-squared:  0.1512
# F-statistic: 171.5 on 3 and 2869 DF,  p-value: < 2.2e-16

# %%
dat[, preds := predict(m)]

# %%
dat[, .(s_rank, preds, gini99)]
# Out:
#      s_rank    preds    gini99
# 1    40.60239  27.38461 0.3799757
# 2    25.48831  30.41911 0.4897381
# 3    42.12478  30.43161 0.4906366
# 4    45.49362  28.76351 0.4170978
# 5    25.05044  25.06918 0.3330419
# 6    23.59640  29.94422 0.4621815
# 7    38.33071  30.53783 0.4988843
# 8    33.46210  29.17821 0.4308186
# 9    37.23212  28.90851 0.4217112
# 10   29.56759  28.34869 0.4047915
# 11   37.40145  27.83336 0.3909757
# 12   38.98377  30.09074 0.4696517
# 13   38.16927  29.98179 0.4640328
# 14   30.57475  27.55362 0.3840202
# 15   28.18999  22.74170 0.2957850
# 16   31.62699  29.64118 0.4485290
# 17   36.60522  29.00720 0.4249595
# 18   35.81879  30.31419 0.4826638
# 19   50.45766  24.95516 0.3310350
# 20   31.96481  29.97280 0.4635864
# 21   36.69456  28.23997 0.4017549
# 22   28.37287  27.96752 0.3944385
# 23   31.38110  28.58773 0.4117333
# 24   38.05599  30.83084 0.5356634
# 25   26.84415  29.46699 0.4414988
# 26   34.37067  27.30969 0.3782180
# 27   34.06462  30.38508 0.4873572
# 28   35.41007  30.20041 0.4757486
# 29   46.84515  27.54200 0.3837385
# 30   29.33228  29.39319 0.4386635
# ⋮    ⋮         ⋮        ⋮
# 2844 33.739662 27.96957 0.3944919
# 2845 19.564171 25.13371 0.3341877
# 2846 21.024826 25.20861 0.3355268
# 2847 16.296318 19.12445 0.2485972
# 2848 18.285927 20.90820 0.2706111
# 2849 15.783745 23.42680 0.3060307
# 2850 20.262688 24.89287 0.3299479
# 2851 23.089233 24.50914 0.3233897
# 2852 18.990845 24.43527 0.3221533
# 2853 18.464630 29.76657 0.4539298
# 2854 10.006027 20.25054 0.2622458
# 2855 14.406075 21.60616 0.2798488
# 2856 20.425850 20.76864 0.2688097
# 2857 14.308136 22.12219 0.2869418
# 2858  9.340820 24.72735 0.3270904
# 2859 31.194710 29.25671 0.4336167
# 2860 25.228088 25.49546 0.3407513
# 2861  5.017662 27.94671 0.3938955
# 2862 19.396492 26.93365 0.3696940
# 2863 13.452011 19.82346 0.2569741
# 2864 17.292061 29.82919 0.4567508
# 2865 12.401688 27.38129 0.3798973
# 2866 13.003647 22.90972 0.2982502
# 2867 11.780212 30.52721 0.4980027
# 2868 11.334450 28.47204 0.4083259
# 2869 18.323318 19.74601 0.2560309
# 2870  6.945885 30.63838 0.6071058
# 2871 22.751038 17.23881 0.2273642
# 2872 25.045143 27.27800 0.3774806
# 2873 14.945755 21.51082 0.2785637
