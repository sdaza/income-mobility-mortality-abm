# %% [markdown]
# # Exploring GSS 2016 for ABM

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# import formula api as alias smf
import statsmodels.formula.api as smf
sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
import os
# %matplotlib inline
# Out:
# The kernel failed to start due to the missing module 'tornado'. Consider installing this module.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
#
# <a href='https://aka.ms/kernelFailuresMissingModule'>Learn more</a>

# %%
os.getcwd()
# Out:
# '/Users/sdaza/GoogleDrive/00Dissertation/dissertation_github/abm/notebooks'

# %%
df = pd.read_stata('../data/GSS2016.DTA', convert_categoricals=False)

# %%
df.columns

# %%
df_sel = df.copy().loc[:, ['age', 'educ', 'realinc']]

# %%
df_sel.loc[:, 'educ'].hist();

# %%
df_sel.loc[:, 'age'].hist()

# %%
df_sel.loc[:, ['age', 'realrinc', 'educ']].dropna(inplace=True)

# %%
sm

# %%
sns.jointplot(x="educ", y="realrinc", data=df_sel, alpha=0.3);

# %%
df_sel.columns = ['age', 'income', 'educ']

# %%
df_sel.to_excel('agents_data.xlsx', index=False)

# %%
# formula: response ~ predictors
est = smf.ols(formula='educ ~ income', data=df_sel).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   educ   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     195.1
# Date:                Sun, 28 Jan 2018   Prob (F-statistic):           1.22e-79
# Time:                        22:05:08   Log-Likelihood:                -30254.
# No. Observations:                2585   AIC:                         6.051e+04
# Df Residuals:                    2582   BIC:                         6.053e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.129e+04   3201.892     -6.648      0.000   -2.76e+04    -1.5e+04
# ...

# %%
# Resampling values

# %%
# s = df_sel.sample(n=10000, replace=True)

# %%
# s['id'] = range(s.shape[0])

# %%
# s.loc[:, ['id', 'age', 'income', 'educ']].to_excel('agents_data.xlsx', index=False)
